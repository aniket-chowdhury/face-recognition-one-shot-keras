# %%
from oneshot import model
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 200, 200, 64)      25664
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 200, 200, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 100, 100, 64)      0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100, 100, 64)      256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 100, 100, 64)      921664
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 100, 100, 64)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 50, 50, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 50, 50, 64)        256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50, 50, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 50, 50, 128)       819328
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 50, 50, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 25, 25, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 25, 25, 128)       512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 25, 25, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 25, 25, 128)       802944
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 25, 25, 128)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 256)       1605888
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 12, 12, 256)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 6, 6, 256)         1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 6, 6, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3072)              28314624
# =================================================================
# Total params: 32,492,672
# Trainable params: 32,491,392
# Non-trainable params: 1,280
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 200, 200, 1)  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 200, 200, 1)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 200, 200, 1)  0           input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 200, 200, 1)  2           lambda_1[0][0]
# ==================================================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None None

# %%
training_dir = "./clean_data"
testing_dir = "./test"
batch_size = 40

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# %%
train_generator = train_datagen.flow_from_directory(
        training_dir,
        target_size=(200, 200),
        batch_size=batch_size,
        class_mode='binary')
# Out:
# Found 400 images belonging to 40 classes.

# %%
import matplotlib.pyplot as plt
train = train_generator.next()
#train

# %%
import collections
collections.Counter(train[1])
# Out:
# Counter({15.0: 2,
#          33.0: 3,
#          5.0: 1,
#          29.0: 1,
#          30.0: 1,
#          18.0: 1,
#          14.0: 3,
#          28.0: 2,
#          9.0: 1,
#          13.0: 1,
#          2.0: 2,
#          8.0: 1,
#          39.0: 2,
#          11.0: 1,
#          7.0: 1,
#          20.0: 1,
#          27.0: 1,
#          19.0: 2,
#          6.0: 1,
#          36.0: 1,
#          38.0: 1,
#          21.0: 1,
#          16.0: 1,
#          1.0: 1,
#          23.0: 3,
#          26.0: 1,
#          17.0: 1,
#          31.0: 1,
#          12.0: 1})

# %%
train_x,train_y = train[0],train[1]

# %%
left_input = np.zeros((10,200,200,3))
right_input = np.zeros((10,200,200,3))
for i in range(10):
    #print(train_x[i].shape)
    left_input[i] = train_x[i]
    right_input[i] = train_x[i+10]

# %%
# Out:
# (array([[[[ 0.52549022,  0.52549022,  0.52549022],
#           [ 0.52549022,  0.52549022,  0.52549022],
#           [ 0.51444864,  0.51444864,  0.51444864],
#           ...,
#           [ 0.50151622,  0.50151622,  0.50151622],
#           [ 0.50319207,  0.50319207,  0.50319207],
#           [ 0.51626217,  0.51626217,  0.51626217]],
#
#          [[ 0.52549022,  0.52549022,  0.52549022],
#           [ 0.52549022,  0.52549022,  0.52549022],
#           [ 0.51444864,  0.51444864,  0.51444864],
#           ...,
#           [ 0.49803925,  0.49803925,  0.49803925],
#           [ 0.49978992,  0.49978992,  0.49978992],
#           [ 0.51372552,  0.51372552,  0.51372552]],
#
#          [[ 0.52549022,  0.52549022,  0.52549022],
#           [ 0.52549022,  0.52549022,  0.52549022],
#           [ 0.51444864,  0.51444864,  0.51444864],
#           ...,
#           [ 0.49803925,  0.49803925,  0.49803925],
#           [ 0.49978992,  0.49978992,  0.49978992],
#           [ 0.51372552,  0.51372552,  0.51372552]],
#
#          ...,
#          [[ 0.39607847,  0.39607847,  0.39607847],
#           [ 0.39607847,  0.39607847,  0.39607847],
#           [ 0.41080052,  0.41080052,  0.41080052],
#           ...,
#           [ 0.41176474,  0.41176474,  0.41176474],
#           [ 0.41482842,  0.41482842,  0.41482842],
#           [ 0.43921572,  0.43921572,  0.43921572]],
#
#          [[ 0.39607847,  0.39607847,  0.39607847],
#           [ 0.39607847,  0.39607847,  0.39607847],
#           [ 0.41080052,  0.41080052,  0.41080052],
#           ...,
#           [ 0.41176474,  0.41176474,  0.41176474],
#           [ 0.41482842,  0.41482842,  0.41482842],
#           [ 0.43921572,  0.43921572,  0.43921572]],
#
#          [[ 0.39607847,  0.39607847,  0.39607847],
#           [ 0.39607847,  0.39607847,  0.39607847],
#           [ 0.40519631,  0.40519631,  0.40519631],
#           ...,
#           [ 0.41367561,  0.41367561,  0.41367561],
#           [ 0.41619849,  0.41619849,  0.41619849],
#           [ 0.43638122,  0.43638122,  0.43638122]]],
#
#
#         [[[ 0.56862748,  0.56862748,  0.56862748],
#           [ 0.56862748,  0.56862748,  0.56862748],
#           [ 0.56862748,  0.56862748,  0.56862748],
#           ...,
#           [ 0.57647061,  0.57647061,  0.57647061],
#           [ 0.57647061,  0.57647061,  0.57647061],
#           [ 0.57647061,  0.57647061,  0.57647061]],
#
#          [[ 0.57226712,  0.57226712,  0.57226712],
#           [ 0.57225674,  0.57225674,  0.57225674],
#           [ 0.57224631,  0.57224631,  0.57224631],
#           ...,
#           [ 0.57248497,  0.57248497,  0.57248497],
#           [ 0.57251096,  0.57251096,  0.57251096],
#           [ 0.57253683,  0.57253683,  0.57253683]],
#
#          [[ 0.57647061,  0.57647061,  0.57647061],
#           [ 0.57647061,  0.57647061,  0.57647061],
#           [ 0.57647061,  0.57647061,  0.57647061],
#           ...,
#           [ 0.55584633,  0.55584633,  0.55584633],
#           [ 0.55585676,  0.55585676,  0.55585676],
#           [ 0.55586714,  0.55586714,  0.55586714]],
#
#          ...,
#          [[ 0.41942701,  0.41942701,  0.41942701],
#           [ 0.41943738,  0.41943738,  0.41943738],
#           [ 0.41944778,  0.41944778,  0.41944778],
#           ...,
#           [ 0.40000004,  0.40000004,  0.40000004],
#           [ 0.40000004,  0.40000004,  0.40000004],
#           [ 0.40000004,  0.40000004,  0.40000004]],
#
#          [[ 0.41216174,  0.41216174,  0.41216174],
#           [ 0.41217211,  0.41217211,  0.41217211],
#           [ 0.41218248,  0.41218248,  0.41218248],
#           ...,
#           [ 0.38649806,  0.38649806,  0.38649806],
#           [ 0.38652402,  0.38652402,  0.38652402],
#           [ 0.38654998,  0.38654998,  0.38654998]],
#
#          [[ 0.41176474,  0.41176474,  0.41176474],
#           [ 0.41176474,  0.41176474,  0.41176474],
#           [ 0.41176474,  0.41176474,  0.41176474],
#           ...,
#           [ 0.38039219,  0.38039219,  0.38039219],
#           [ 0.38039219,  0.38039219,  0.38039219],
#           [ 0.38039219,  0.38039219,  0.38039219]]],
#
#
#         [[[ 0.57354701,  0.57354701,  0.57354701],
#           [ 0.5440225 ,  0.5440225 ,  0.5440225 ],
#           [ 0.52554494,  0.52554494,  0.52554494],
#           ...,
#           [ 0.60320264,  0.60320264,  0.60320264],
#           [ 0.59256214,  0.59256214,  0.59256214],
#           [ 0.59253812,  0.59253812,  0.59253812]],
#
#          [[ 0.53830838,  0.53830838,  0.53830838],
#           [ 0.4728741 ,  0.4728741 ,  0.4728741 ],
#           [ 0.4319756 ,  0.4319756 ,  0.4319756 ],
#           ...,
#           [ 0.58989775,  0.58989775,  0.58989775],
#           [ 0.58865821,  0.58865821,  0.58865821],
#           [ 0.58864617,  0.58864617,  0.58864617]],
#
#          [[ 0.50196081,  0.50196081,  0.50196081],
#           [ 0.3954314 ,  0.3954314 ,  0.3954314 ],
#           [ 0.32941177,  0.32941177,  0.32941177],
#           ...,
#           [ 0.58823532,  0.58823532,  0.58823532],
#           [ 0.58823532,  0.58823532,  0.58823532],
#           [ 0.58823532,  0.58823532,  0.58823532]],
#
#          ...,
#          [[ 0.35686275,  0.35686275,  0.35686275],
#           [ 0.36896837,  0.36896837,  0.36896837],
#           [ 0.37647063,  0.37647063,  0.37647063],
#           ...,
#           [ 0.33333334,  0.33333334,  0.33333334],
#           [ 0.33333334,  0.33333334,  0.33333334],
#           [ 0.33333334,  0.33333334,  0.33333334]],
#
#          [[ 0.35686275,  0.35686275,  0.35686275],
#           [ 0.36951619,  0.36951619,  0.36951619],
#           [ 0.37736988,  0.37736988,  0.37736988],
#           ...,
#           [ 0.33885399,  0.33885399,  0.33885399],
#           [ 0.3365818 ,  0.3365818 ,  0.3365818 ],
#           [ 0.33659378,  0.33659378,  0.33659378]],
#
#          [[ 0.36013818,  0.36013818,  0.36013818],
#           [ 0.37060645,  0.37060645,  0.37060645],
#           [ 0.3769969 ,  0.3769969 ,  0.3769969 ],
#           ...,
#           [ 0.3348777 ,  0.3348777 ,  0.3348777 ],
#           [ 0.33422673,  0.33422673,  0.33422673],
#           [ 0.33421475,  0.33421475,  0.33421475]]],
#
#
#         ...,
#         [[[ 0.227451  ,  0.227451  ,  0.227451  ],
#           [ 0.227451  ,  0.227451  ,  0.227451  ],
#           [ 0.227451  ,  0.227451  ,  0.227451  ],
#           ...,
#           [ 0.20392159,  0.20392159,  0.20392159],
#           [ 0.20392159,  0.20392159,  0.20392159],
#           [ 0.20392159,  0.20392159,  0.20392159]],
#
#          [[ 0.227451  ,  0.227451  ,  0.227451  ],
#           [ 0.227451  ,  0.227451  ,  0.227451  ],
#           [ 0.227451  ,  0.227451  ,  0.227451  ],
#           ...,
#           [ 0.20392159,  0.20392159,  0.20392159],
#           [ 0.20392159,  0.20392159,  0.20392159],
#           [ 0.20392159,  0.20392159,  0.20392159]],
#
#          [[ 0.227451  ,  0.227451  ,  0.227451  ],
#           [ 0.227451  ,  0.227451  ,  0.227451  ],
#           [ 0.227451  ,  0.227451  ,  0.227451  ],
#           ...,
#           [ 0.20392159,  0.20392159,  0.20392159],
#           [ 0.20392159,  0.20392159,  0.20392159],
#           [ 0.20392159,  0.20392159,  0.20392159]],
#
#          ...,
#          [[ 0.56078434,  0.56078434,  0.56078434],
#           [ 0.56078434,  0.56078434,  0.56078434],
#           [ 0.56078434,  0.56078434,  0.56078434],
#           ...,
#           [ 0.52941179,  0.52941179,  0.52941179],
#           [ 0.52941179,  0.52941179,  0.52941179],
#           [ 0.52941179,  0.52941179,  0.52941179]],
#
#          [[ 0.56078434,  0.56078434,  0.56078434],
#           [ 0.56078434,  0.56078434,  0.56078434],
#           [ 0.56078434,  0.56078434,  0.56078434],
#           ...,
#           [ 0.52941179,  0.52941179,  0.52941179],
#           [ 0.52941179,  0.52941179,  0.52941179],
#           [ 0.52941179,  0.52941179,  0.52941179]],
#
#          [[ 0.56078434,  0.56078434,  0.56078434],
#           [ 0.56078434,  0.56078434,  0.56078434],
#           [ 0.56078434,  0.56078434,  0.56078434],
#           ...,
#           [ 0.52941179,  0.52941179,  0.52941179],
#           [ 0.52941179,  0.52941179,  0.52941179],
#           [ 0.52941179,  0.52941179,  0.52941179]]],
#
#
#         [[[ 0.58513618,  0.58513618,  0.58513618],
#           [ 0.59826607,  0.59826607,  0.59826607],
#           [ 0.60000002,  0.60000002,  0.60000002],
#           ...,
#           [ 0.50011039,  0.50011039,  0.50011039],
#           [ 0.47119206,  0.47119206,  0.47119206],
#           [ 0.46274513,  0.46274513,  0.46274513]],
#
#          [[ 0.58545655,  0.58545655,  0.58545655],
#           [ 0.60375339,  0.60375339,  0.60375339],
#           [ 0.60622758,  0.60622758,  0.60622758],
#           ...,
#           [ 0.46530434,  0.46530434,  0.46530434],
#           [ 0.43731931,  0.43731931,  0.43731931],
#           [ 0.42985058,  0.42985058,  0.42985058]],
#
#          [[ 0.59404004,  0.59404004,  0.59404004],
#           [ 0.61544895,  0.61544895,  0.61544895],
#           [ 0.61815619,  0.61815619,  0.61815619],
#           ...,
#           [ 0.42512676,  0.42512676,  0.42512676],
#           [ 0.4066048 ,  0.4066048 ,  0.4066048 ],
#           [ 0.40234202,  0.40234202,  0.40234202]],
#
#          ...,
#          [[ 0.41801199,  0.41801199,  0.41801199],
#           [ 0.55127919,  0.55127919,  0.55127919],
#           [ 0.5687744 ,  0.5687744 ,  0.5687744 ],
#           ...,
#           [ 0.22942351,  0.22942351,  0.22942351],
#           [ 0.23375149,  0.23375149,  0.23375149],
#           [ 0.23529413,  0.23529413,  0.23529413]],
#
#          [[ 0.5026958 ,  0.5026958 ,  0.5026958 ],
#           [ 0.51056182,  0.51056182,  0.51056182],
#           [ 0.5113945 ,  0.5113945 ,  0.5113945 ],
#           ...,
#           [ 0.234439  ,  0.234439  ,  0.234439  ],
#           [ 0.23239958,  0.23239958,  0.23239958],
#           [ 0.23187956,  0.23187956,  0.23187956]],
#
#          [[ 0.59693122,  0.59693122,  0.59693122],
#           [ 0.48532704,  0.48532704,  0.48532704],
#           [ 0.47058827,  0.47058827,  0.47058827],
#           ...,
#           [ 0.23529413,  0.23529413,  0.23529413],
#           [ 0.23221725,  0.23221725,  0.23221725],
#           [ 0.23137257,  0.23137257,  0.23137257]]],
#
#
#         [[[ 0.50588238,  0.50588238,  0.50588238],
#           [ 0.50588238,  0.50588238,  0.50588238],
#           [ 0.50588238,  0.50588238,  0.50588238],
#           ...,
#           [ 0.52941179,  0.52941179,  0.52941179],
#           [ 0.52941179,  0.52941179,  0.52941179],
#           [ 0.52941179,  0.52941179,  0.52941179]],
#
#          [[ 0.50588238,  0.50588238,  0.50588238],
#           [ 0.50588238,  0.50588238,  0.50588238],
#           [ 0.50588238,  0.50588238,  0.50588238],
#           ...,
#           [ 0.52941179,  0.52941179,  0.52941179],
#           [ 0.52941179,  0.52941179,  0.52941179],
#           [ 0.52941179,  0.52941179,  0.52941179]],
#
#          [[ 0.50588238,  0.50588238,  0.50588238],
#           [ 0.50588238,  0.50588238,  0.50588238],
#           [ 0.50588238,  0.50588238,  0.50588238],
#           ...,
#           [ 0.52941179,  0.52941179,  0.52941179],
#           [ 0.52941179,  0.52941179,  0.52941179],
#           [ 0.52941179,  0.52941179,  0.52941179]],
#
#          ...,
#          [[ 0.34901962,  0.34901962,  0.34901962],
#           [ 0.34901962,  0.34901962,  0.34901962],
#           [ 0.34901962,  0.34901962,  0.34901962],
#           ...,
#           [ 0.4039216 ,  0.4039216 ,  0.4039216 ],
#           [ 0.4039216 ,  0.4039216 ,  0.4039216 ],
#           [ 0.4039216 ,  0.4039216 ,  0.4039216 ]],
#
#          [[ 0.34901962,  0.34901962,  0.34901962],
#           [ 0.34901962,  0.34901962,  0.34901962],
#           [ 0.34901962,  0.34901962,  0.34901962],
#           ...,
#           [ 0.4039216 ,  0.4039216 ,  0.4039216 ],
#           [ 0.4039216 ,  0.4039216 ,  0.4039216 ],
#           [ 0.4039216 ,  0.4039216 ,  0.4039216 ]],
#
#          [[ 0.34901962,  0.34901962,  0.34901962],
#           [ 0.34901962,  0.34901962,  0.34901962],
#           [ 0.34901962,  0.34901962,  0.34901962],
#           ...,
#           [ 0.4039216 ,  0.4039216 ,  0.4039216 ],
#           [ 0.4039216 ,  0.4039216 ,  0.4039216 ],
#           [ 0.4039216 ,  0.4039216 ,  0.4039216 ]]]]),
#  array([[[[ 0.36807621,  0.36807621,  0.36807621],
#           [ 0.37987894,  0.37987894,  0.37987894],
#           [ 0.38614562,  0.38614562,  0.38614562],
#           ...,
#           [ 0.37609065,  0.37609065,  0.37609065],
#           [ 0.36889464,  0.36889464,  0.36889464],
#           [ 0.36890799,  0.36890799,  0.36890799]],
#
#          [[ 0.37647063,  0.37647063,  0.37647063],
#           [ 0.38415304,  0.38415304,  0.38415304],
#           [ 0.38823533,  0.38823533,  0.38823533],
#           ...,
#           [ 0.37804496,  0.37804496,  0.37804496],
#           [ 0.37254903,  0.37254903,  0.37254903],
#           [ 0.37254903,  0.37254903,  0.37254903]],
#
#          [[ 0.38701251,  0.38701251,  0.38701251],
#           [ 0.38781485,  0.38781485,  0.38781485],
#           [ 0.38823533,  0.38823533,  0.38823533],
#           ...,
#           [ 0.37804496,  0.37804496,  0.37804496],
#           [ 0.37254903,  0.37254903,  0.37254903],
#           [ 0.37254903,  0.37254903,  0.37254903]],
#
#          ...,
#          [[ 0.28734389,  0.28734389,  0.28734389],
#           [ 0.30572999,  0.30572999,  0.30572999],
#           [ 0.31550357,  0.31550357,  0.31550357],
#           ...,
#           [ 0.32167575,  0.32167575,  0.32167575],
#           [ 0.33714971,  0.33714971,  0.33714971],
#           [ 0.33715636,  0.33715636,  0.33715636]],
#
#          [[ 0.27843139,  0.27843139,  0.27843139],
#           [ 0.30147874,  0.30147874,  0.30147874],
#           [ 0.3137255 ,  0.3137255 ,  0.3137255 ],
#           ...,
#           [ 0.32194072,  0.32194072,  0.32194072],
#           [ 0.34117648,  0.34117648,  0.34117648],
#           [ 0.34117648,  0.34117648,  0.34117648]],
#
#          [[ 0.29218316,  0.29218316,  0.29218316],
#           [ 0.29816312,  0.29816312,  0.29816312],
#           [ 0.3013089 ,  0.3013089 ,  0.3013089 ],
#           ...,
#           [ 0.31267622,  0.31267622,  0.31267622],
#           [ 0.34843814,  0.34843814,  0.34843814],
#           [ 0.34844702,  0.34844702,  0.34844702]]],
#
#
#         [[[ 0.50458544,  0.50458544,  0.50458544],
#           [ 0.49803925,  0.49803925,  0.49803925],
#           [ 0.50140172,  0.50140172,  0.50140172],
#           ...,
#           [ 0.52156866,  0.52156866,  0.52156866],
#           [ 0.52156866,  0.52156866,  0.52156866],
#           [ 0.51743758,  0.51743758,  0.51743758]],
#
#          [[ 0.50458544,  0.50458544,  0.50458544],
#           [ 0.49803925,  0.49803925,  0.49803925],
#           [ 0.50140172,  0.50140172,  0.50140172],
#           ...,
#           [ 0.52156866,  0.52156866,  0.52156866],
#           [ 0.52156866,  0.52156866,  0.52156866],
#           [ 0.51743758,  0.51743758,  0.51743758]],
#
#          [[ 0.50458544,  0.50458544,  0.50458544],
#           [ 0.49803925,  0.49803925,  0.49803925],
#           [ 0.50140172,  0.50140172,  0.50140172],
#           ...,
#           [ 0.52156866,  0.52156866,  0.52156866],
#           [ 0.52156866,  0.52156866,  0.52156866],
#           [ 0.51743758,  0.51743758,  0.51743758]],
#
#          ...,
#          [[ 0.85258627,  0.85258627,  0.85258627],
#           [ 0.8705883 ,  0.8705883 ,  0.8705883 ],
#           [ 0.82183212,  0.82183212,  0.82183212],
#           ...,
#           [ 0.88627458,  0.88627458,  0.88627458],
#           [ 0.88627458,  0.88627458,  0.88627458],
#           [ 0.84083277,  0.84083277,  0.84083277]],
#
#          [[ 0.85258627,  0.85258627,  0.85258627],
#           [ 0.8705883 ,  0.8705883 ,  0.8705883 ],
#           [ 0.82183212,  0.82183212,  0.82183212],
#           ...,
#           [ 0.88627458,  0.88627458,  0.88627458],
#           [ 0.88627458,  0.88627458,  0.88627458],
#           [ 0.84083277,  0.84083277,  0.84083277]],
#
#          [[ 0.85258627,  0.85258627,  0.85258627],
#           [ 0.8705883 ,  0.8705883 ,  0.8705883 ],
#           [ 0.82183212,  0.82183212,  0.82183212],
#           ...,
#           [ 0.88627458,  0.88627458,  0.88627458],
#           [ 0.88627458,  0.88627458,  0.88627458],
#           [ 0.84083277,  0.84083277,  0.84083277]]],
#
#
#         [[[ 0.15686275,  0.15686275,  0.15686275],
#           [ 0.15686275,  0.15686275,  0.15686275],
#           [ 0.15686275,  0.15686275,  0.15686275],
#           ...,
#           [ 0.19607845,  0.19607845,  0.19607845],
#           [ 0.19607845,  0.19607845,  0.19607845],
#           [ 0.19607845,  0.19607845,  0.19607845]],
#
#          [[ 0.15686275,  0.15686275,  0.15686275],
#           [ 0.15686275,  0.15686275,  0.15686275],
#           [ 0.15686275,  0.15686275,  0.15686275],
#           ...,
#           [ 0.19607845,  0.19607845,  0.19607845],
#           [ 0.19607845,  0.19607845,  0.19607845],
#           [ 0.19607845,  0.19607845,  0.19607845]],
#
#          [[ 0.16107592,  0.16107592,  0.16107592],
#           [ 0.16106117,  0.16106117,  0.16106117],
#           [ 0.16104642,  0.16104642,  0.16104642],
#           ...,
#           [ 0.19771431,  0.19771431,  0.19771431],
#           [ 0.1976959 ,  0.1976959 ,  0.1976959 ],
#           [ 0.19767746,  0.19767746,  0.19767746]],
#
#          ...,
#          [[ 0.15366316,  0.15366316,  0.15366316],
#           [ 0.15365948,  0.15365948,  0.15365948],
#           [ 0.1536558 ,  0.1536558 ,  0.1536558 ],
#           ...,
#           [ 0.2509473 ,  0.2509473 ,  0.2509473 ],
#           [ 0.25091782,  0.25091782,  0.25091782],
#           [ 0.25088832,  0.25088832,  0.25088832]],
#
#          [[ 0.15686275,  0.15686275,  0.15686275],
#           [ 0.15686275,  0.15686275,  0.15686275],
#           [ 0.15686275,  0.15686275,  0.15686275],
#           ...,
#           [ 0.25437328,  0.25437328,  0.25437328],
#           [ 0.25436956,  0.25436956,  0.25436956],
#           [ 0.25436589,  0.25436589,  0.25436589]],
#
#          [[ 0.15686275,  0.15686275,  0.15686275],
#           [ 0.15686275,  0.15686275,  0.15686275],
#           [ 0.15686275,  0.15686275,  0.15686275],
#           ...,
#           [ 0.25490198,  0.25490198,  0.25490198],
#           [ 0.25490198,  0.25490198,  0.25490198],
#           [ 0.25490198,  0.25490198,  0.25490198]]],
#
#
#         ...,
#         [[[ 0.17308578,  0.17308578,  0.17308578],
#           [ 0.18377009,  0.18377009,  0.18377009],
#           [ 0.18431373,  0.18431373,  0.18431373],
#           ...,
#           [ 0.21608615,  0.21608615,  0.21608615],
#           [ 0.21258201,  0.21258201,  0.21258201],
#           [ 0.21212813,  0.21212813,  0.21212813]],
#
#          [[ 0.19372143,  0.19372143,  0.19372143],
#           [ 0.17573838,  0.17573838,  0.17573838],
#           [ 0.17478597,  0.17478597,  0.17478597],
#           ...,
#           [ 0.20743822,  0.20743822,  0.20743822],
#           [ 0.21930271,  0.21930271,  0.21930271],
#           [ 0.2211203 ,  0.2211203 ,  0.2211203 ]],
#
#          [[ 0.19978227,  0.19978227,  0.19978227],
#           [ 0.19553354,  0.19553354,  0.19553354],
#           [ 0.19540691,  0.19540691,  0.19540691],
#           ...,
#           [ 0.20000002,  0.20000002,  0.20000002],
#           [ 0.20338252,  0.20338252,  0.20338252],
#           [ 0.20392159,  0.20392159,  0.20392159]],
#
#          ...,
#          [[ 0.20624749,  0.20624749,  0.20624749],
#           [ 0.25254616,  0.25254616,  0.25254616],
#           [ 0.25490198,  0.25490198,  0.25490198],
#           ...,
#           [ 0.56612569,  0.56612569,  0.56612569],
#           [ 0.39448211,  0.39448211,  0.39448211],
#           [ 0.36740842,  0.36740842,  0.36740842]],
#
#          [[ 0.28429753,  0.28429753,  0.28429753],
#           [ 0.27122158,  0.27122158,  0.27122158],
#           [ 0.27059805,  0.27059805,  0.27059805],
#           ...,
#           [ 0.53888655,  0.53888655,  0.53888655],
#           [ 0.47386864,  0.47386864,  0.47386864],
#           [ 0.46387285,  0.46387285,  0.46387285]],
#
#          [[ 0.33026171,  0.33026171,  0.33026171],
#           [ 0.25850129,  0.25850129,  0.25850129],
#           [ 0.25476614,  0.25476614,  0.25476614],
#           ...,
#           [ 0.51372552,  0.51372552,  0.51372552],
#           [ 0.53740317,  0.53740317,  0.53740317],
#           [ 0.5411765 ,  0.5411765 ,  0.5411765 ]]],
#
#
#         [[[ 0.57647061,  0.57647061,  0.57647061],
#           [ 0.5453099 ,  0.5453099 ,  0.5453099 ],
#           [ 0.43921572,  0.43921572,  0.43921572],
#           ...,
#           [ 0.57123083,  0.57123083,  0.57123083],
#           [ 0.56862748,  0.56862748,  0.56862748],
#           [ 0.58300531,  0.58300531,  0.58300531]],
#
#          [[ 0.57647061,  0.57647061,  0.57647061],
#           [ 0.5453099 ,  0.5453099 ,  0.5453099 ],
#           [ 0.43921572,  0.43921572,  0.43921572],
#           ...,
#           [ 0.57123083,  0.57123083,  0.57123083],
#           [ 0.56862748,  0.56862748,  0.56862748],
#           [ 0.58300531,  0.58300531,  0.58300531]],
#
#          [[ 0.57647061,  0.57647061,  0.57647061],
#           [ 0.5453099 ,  0.5453099 ,  0.5453099 ],
#           [ 0.43921572,  0.43921572,  0.43921572],
#           ...,
#           [ 0.57123083,  0.57123083,  0.57123083],
#           [ 0.56862748,  0.56862748,  0.56862748],
#           [ 0.58300531,  0.58300531,  0.58300531]],
#
#          ...,
#          [[ 0.45882356,  0.45882356,  0.45882356],
#           [ 0.44724956,  0.44724956,  0.44724956],
#           [ 0.40784317,  0.40784317,  0.40784317],
#           ...,
#           [ 0.47584471,  0.47584471,  0.47584471],
#           [ 0.48235297,  0.48235297,  0.48235297],
#           [ 0.45359728,  0.45359728,  0.45359728]],
#
#          [[ 0.45882356,  0.45882356,  0.45882356],
#           [ 0.44724956,  0.44724956,  0.44724956],
#           [ 0.40784317,  0.40784317,  0.40784317],
#           ...,
#           [ 0.47584471,  0.47584471,  0.47584471],
#           [ 0.48235297,  0.48235297,  0.48235297],
#           [ 0.45359728,  0.45359728,  0.45359728]],
#
#          [[ 0.45882356,  0.45882356,  0.45882356],
#           [ 0.44724956,  0.44724956,  0.44724956],
#           [ 0.40784317,  0.40784317,  0.40784317],
#           ...,
#           [ 0.47584471,  0.47584471,  0.47584471],
#           [ 0.48235297,  0.48235297,  0.48235297],
#           [ 0.45359728,  0.45359728,  0.45359728]]],
#
#
#         [[[ 0.06666667,  0.06666667,  0.06666667],
#           [ 0.06666667,  0.06666667,  0.06666667],
#           [ 0.06666667,  0.06666667,  0.06666667],
#           ...,
#           [ 0.09019608,  0.09019608,  0.09019608],
#           [ 0.09019608,  0.09019608,  0.09019608],
#           [ 0.09019608,  0.09019608,  0.09019608]],
#
#          [[ 0.07018768,  0.07018768,  0.07018768],
#           [ 0.07021117,  0.07021117,  0.07021117],
#           [ 0.07023468,  0.07023468,  0.07023468],
#           ...,
#           [ 0.09562985,  0.09562985,  0.09562985],
#           [ 0.09564552,  0.09564552,  0.09564552],
#           [ 0.09566119,  0.09566119,  0.09566119]],
#
#          [[ 0.09013139,  0.09013139,  0.09013139],
#           [ 0.09012747,  0.09012747,  0.09012747],
#           [ 0.09012356,  0.09012356,  0.09012356],
#           ...,
#           [ 0.10671866,  0.10671866,  0.10671866],
#           [ 0.10672258,  0.10672258,  0.10672258],
#           [ 0.10672649,  0.10672649,  0.10672649]],
#
#          ...,
#          [[ 0.6631611 ,  0.6631611 ,  0.6631611 ],
#           [ 0.66316891,  0.66316891,  0.66316891],
#           [ 0.66317677,  0.66317677,  0.66317677],
#           ...,
#           [ 0.76176715,  0.76176715,  0.76176715],
#           [ 0.76175541,  0.76175541,  0.76175541],
#           [ 0.76174366,  0.76174366,  0.76174366]],
#
#          [[ 0.66995996,  0.66995996,  0.66995996],
#           [ 0.66996783,  0.66996783,  0.66996783],
#           [ 0.66997564,  0.66997564,  0.66997564],
#           ...,
#           [ 0.75294125,  0.75294125,  0.75294125],
#           [ 0.75294125,  0.75294125,  0.75294125],
#           [ 0.75294125,  0.75294125,  0.75294125]],
#
#          [[ 0.67058825,  0.67058825,  0.67058825],
#           [ 0.67058825,  0.67058825,  0.67058825],
#           [ 0.67058825,  0.67058825,  0.67058825],
#           ...,
#           [ 0.75294125,  0.75294125,  0.75294125],
#           [ 0.75294125,  0.75294125,  0.75294125],
#           [ 0.75294125,  0.75294125,  0.75294125]]]]))
