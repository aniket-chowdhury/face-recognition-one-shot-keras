# %%
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 200, 200, 64)      25664
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 200, 200, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 100, 100, 64)      0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100, 100, 64)      256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 100, 100, 64)      921664
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 100, 100, 64)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 50, 50, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 50, 50, 64)        256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50, 50, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 50, 50, 128)       819328
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 50, 50, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 25, 25, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 25, 25, 128)       512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 25, 25, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 25, 25, 128)       802944
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 25, 25, 128)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 256)       1605888
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 12, 12, 256)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 6, 6, 256)         1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 6, 6, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3072)              28314624
# =================================================================
# Total params: 32,492,672
# Trainable params: 32,491,392
# Non-trainable params: 1,280
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 200, 200, 1)  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 200, 200, 1)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 200, 200, 1)  0           input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 200, 200, 1)  2           lambda_1[0][0]
# ==================================================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None None

# %%
import pydot

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.np()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
# Out:
# Found 400 images belonging to 40 classes.

# %%
import numpy as np
import matplotlib.pyplot as plt
import re

def read_pgm(filename, byteorder='>'):
    """Return image data from a raw PGM file as numpy array.

    Format specification: http://netpbm.sourceforge.net/doc/pgm.html

    """
    with open(filename, 'rb') as f:
        buffer = f.read()
    try:
        header, width, height, maxval = re.search(
            b"(^P5\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n]\s)*)", buffer).groups()
    except AttributeError:
        raise ValueError("Not a raw PGM file: '%s'" % filename)
    return np.frombuffer(buffer,
                            dtype='u1' if int(maxval) < 256 else byteorder+'u2',
                            count=int(width)*int(height),
                            offset=len(header)
                            ).reshape((int(height), int(width)))

# %%
import os

if not os.path.exists('clean_data'):
    os.makedirs('clean_data')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
s=1
i=1
images = np.array([])
for s in range(1,41):
    for i in range(1,11):
        try:
            if os.path.exists("clean_data/s"+str(s)+"/"+str(i)+".png"):
                print("s"+str(s)+"/"+str(i)+".png exists. skipping")
                continue
            image = read_pgm("data/s"+str(s)+"/"+str(i)+".pgm", byteorder='<')

            plt.gca().set_axis_off()
            plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
                        hspace = 0, wspace = 0)
            plt.margins(0,0)
            plt.gca().xaxis.set_major_locator(plt.NullLocator())
            plt.gca().yaxis.set_major_locator(plt.NullLocator())

            plt.imshow(image, plt.cm.gray)

            plt.axis('off')

            if not os.path.exists('clean_data/s'+str(s)):
                os.makedirs('clean_data/s'+str(s))
            
            plt.savefig("clean_data/s"+str(s)+"/"+str(i)+".png",bbox_inches="tight",pad_inches=0.0)
            #plt.show()
            #plt.savefig("data/s"+str(s)+"/"+str(i)+".png")
            print("processing s"+str(s)+"/"+str(i)+".png")
        except Exception as e:
            print(e)
# Out:
# processing s1/1.png
# processing s1/2.png
# processing s1/3.png
# processing s1/4.png
# processing s1/5.png
# processing s1/6.png
# processing s1/7.png
# processing s1/8.png
# processing s1/9.png
# processing s1/10.png
# processing s2/1.png
# processing s2/2.png
# processing s2/3.png
# processing s2/4.png
# processing s2/5.png
# processing s2/6.png
# processing s2/7.png
# processing s2/8.png
# processing s2/9.png
# processing s2/10.png
# processing s3/1.png
# processing s3/2.png
# processing s3/3.png
# processing s3/4.png
# processing s3/5.png
# processing s3/6.png
# processing s3/7.png
# processing s3/8.png
# processing s3/9.png
# processing s3/10.png
# processing s4/1.png
# processing s4/2.png
# processing s4/3.png
# processing s4/4.png
# processing s4/5.png
# processing s4/6.png
# processing s4/7.png
# processing s4/8.png
# processing s4/9.png
# processing s4/10.png
# processing s5/1.png
# processing s5/2.png
# processing s5/3.png
# processing s5/4.png
# processing s5/5.png
# processing s5/6.png
# processing s5/7.png
# processing s5/8.png
# processing s5/9.png
# processing s5/10.png
# processing s6/1.png
# processing s6/2.png
# processing s6/3.png
# processing s6/4.png
# processing s6/5.png
# processing s6/6.png
# processing s6/7.png
# processing s6/8.png
# processing s6/9.png
# processing s6/10.png
# processing s7/1.png
# processing s7/2.png
# processing s7/3.png
# processing s7/4.png
# processing s7/5.png
# processing s7/6.png
# processing s7/7.png
# processing s7/8.png
# processing s7/9.png
# processing s7/10.png
# processing s8/1.png
# processing s8/2.png
# processing s8/3.png
# processing s8/4.png
# processing s8/5.png
# processing s8/6.png
# processing s8/7.png
# processing s8/8.png
# processing s8/9.png
# processing s8/10.png
# processing s9/1.png
# processing s9/2.png
# processing s9/3.png
# processing s9/4.png
# processing s9/5.png
# processing s9/6.png
# processing s9/7.png
# processing s9/8.png
# processing s9/9.png
# processing s9/10.png
# processing s10/1.png
# processing s10/2.png
# processing s10/3.png
# processing s10/4.png
# processing s10/5.png
# processing s10/6.png
# processing s10/7.png
# processing s10/8.png
# processing s10/9.png
# processing s10/10.png
# processing s11/1.png
# processing s11/2.png
# processing s11/3.png
# processing s11/4.png
# processing s11/5.png
# processing s11/6.png
# processing s11/7.png
# processing s11/8.png
# processing s11/9.png
# processing s11/10.png
# processing s12/1.png
# processing s12/2.png
# processing s12/3.png
# processing s12/4.png
# processing s12/5.png
# processing s12/6.png
# processing s12/7.png
# processing s12/8.png
# processing s12/9.png
# processing s12/10.png
# processing s13/1.png
# processing s13/2.png
# processing s13/3.png
# processing s13/4.png
# processing s13/5.png
# processing s13/6.png
# processing s13/7.png
# processing s13/8.png
# processing s13/9.png
# processing s13/10.png
# processing s14/1.png
# processing s14/2.png
# processing s14/3.png
# processing s14/4.png
# processing s14/5.png
# processing s14/6.png
# processing s14/7.png
# processing s14/8.png
# processing s14/9.png
# processing s14/10.png
# processing s15/1.png
# processing s15/2.png
# processing s15/3.png
# processing s15/4.png
# processing s15/5.png
# processing s15/6.png
# processing s15/7.png
# processing s15/8.png
# processing s15/9.png
# processing s15/10.png
# processing s16/1.png
# processing s16/2.png
# processing s16/3.png
# processing s16/4.png
# processing s16/5.png
# processing s16/6.png
# processing s16/7.png
# processing s16/8.png
# processing s16/9.png
# processing s16/10.png
# processing s17/1.png
# processing s17/2.png
# processing s17/3.png
# processing s17/4.png
# processing s17/5.png
# processing s17/6.png
# processing s17/7.png
# processing s17/8.png
# processing s17/9.png
# processing s17/10.png
# processing s18/1.png
# processing s18/2.png
# processing s18/3.png
# processing s18/4.png
# processing s18/5.png
# processing s18/6.png
# processing s18/7.png
# processing s18/8.png
# processing s18/9.png
# processing s18/10.png
# processing s19/1.png
# processing s19/2.png
# processing s19/3.png
# processing s19/4.png
# processing s19/5.png
# processing s19/6.png
# processing s19/7.png
# processing s19/8.png
# processing s19/9.png
# processing s19/10.png
# processing s20/1.png
# processing s20/2.png
# processing s20/3.png
# processing s20/4.png
# processing s20/5.png
# processing s20/6.png
# processing s20/7.png
# processing s20/8.png
# processing s20/9.png
# processing s20/10.png
# processing s21/1.png
# processing s21/2.png
# processing s21/3.png
# processing s21/4.png
# processing s21/5.png
# processing s21/6.png
# processing s21/7.png
# processing s21/8.png
# processing s21/9.png
# processing s21/10.png
# processing s22/1.png
# processing s22/2.png
# processing s22/3.png
# processing s22/4.png
# processing s22/5.png
# processing s22/6.png
# processing s22/7.png
# processing s22/8.png
# processing s22/9.png
# processing s22/10.png
# processing s23/1.png
# processing s23/2.png
# processing s23/3.png
# processing s23/4.png
# processing s23/5.png
# processing s23/6.png
# processing s23/7.png
# processing s23/8.png
# processing s23/9.png
# processing s23/10.png
# processing s24/1.png
# processing s24/2.png
# processing s24/3.png
# processing s24/4.png
# processing s24/5.png
# processing s24/6.png
# processing s24/7.png
# processing s24/8.png
# processing s24/9.png
# processing s24/10.png
# processing s25/1.png
# processing s25/2.png
# processing s25/3.png
# processing s25/4.png
# processing s25/5.png
# processing s25/6.png
# processing s25/7.png
# processing s25/8.png
# processing s25/9.png
# processing s25/10.png
# processing s26/1.png
# processing s26/2.png
# processing s26/3.png
# processing s26/4.png
# processing s26/5.png
# processing s26/6.png
# processing s26/7.png
# processing s26/8.png
# processing s26/9.png
# processing s26/10.png
# processing s27/1.png
# processing s27/2.png
# processing s27/3.png
# processing s27/4.png
# processing s27/5.png
# processing s27/6.png
# processing s27/7.png
# processing s27/8.png
# processing s27/9.png
# processing s27/10.png
# processing s28/1.png
# processing s28/2.png
# processing s28/3.png
# processing s28/4.png
# processing s28/5.png
# processing s28/6.png
# processing s28/7.png
# processing s28/8.png
# processing s28/9.png
# processing s28/10.png
# processing s29/1.png
# processing s29/2.png
# processing s29/3.png
# processing s29/4.png
# processing s29/5.png
# processing s29/6.png
# processing s29/7.png
# processing s29/8.png
# processing s29/9.png
# processing s29/10.png
# processing s30/1.png
# processing s30/2.png
# processing s30/3.png
# processing s30/4.png
# processing s30/5.png
# processing s30/6.png
# processing s30/7.png
# processing s30/8.png
# processing s30/9.png
# processing s30/10.png
# processing s31/1.png
# processing s31/2.png
# processing s31/3.png
# processing s31/4.png
# processing s31/5.png
# processing s31/6.png
# processing s31/7.png
# processing s31/8.png
# processing s31/9.png
# processing s31/10.png
# processing s32/1.png
# processing s32/2.png
# processing s32/3.png
# processing s32/4.png
# processing s32/5.png
# processing s32/6.png
# processing s32/7.png
# processing s32/8.png
# processing s32/9.png
# processing s32/10.png
# processing s33/1.png
# processing s33/2.png
# processing s33/3.png
# processing s33/4.png
# processing s33/5.png
# processing s33/6.png
# processing s33/7.png
# processing s33/8.png
# processing s33/9.png
# processing s33/10.png
# processing s34/1.png
# processing s34/2.png
# processing s34/3.png
# processing s34/4.png
# processing s34/5.png
# processing s34/6.png
# processing s34/7.png
# processing s34/8.png
# processing s34/9.png
# processing s34/10.png
# processing s35/1.png
# processing s35/2.png
# processing s35/3.png
# processing s35/4.png
# processing s35/5.png
# processing s35/6.png
# processing s35/7.png
# processing s35/8.png
# processing s35/9.png
# processing s35/10.png
# processing s36/1.png
# processing s36/2.png
# processing s36/3.png
# processing s36/4.png
# processing s36/5.png
# processing s36/6.png
# processing s36/7.png
# processing s36/8.png
# processing s36/9.png
# processing s36/10.png
# processing s37/1.png
# processing s37/2.png
# processing s37/3.png
# processing s37/4.png
# processing s37/5.png
# processing s37/6.png
# processing s37/7.png
# processing s37/8.png
# processing s37/9.png
# processing s37/10.png
# processing s38/1.png
# processing s38/2.png
# processing s38/3.png
# processing s38/4.png
# processing s38/5.png
# processing s38/6.png
# processing s38/7.png
# processing s38/8.png
# processing s38/9.png
# processing s38/10.png
# processing s39/1.png
# processing s39/2.png
# processing s39/3.png
# processing s39/4.png
# processing s39/5.png
# processing s39/6.png
# processing s39/7.png
# processing s39/8.png
# processing s39/9.png
# processing s39/10.png
# processing s40/1.png
# processing s40/2.png
# processing s40/3.png
# processing s40/4.png
# processing s40/5.png
# processing s40/6.png
# processing s40/7.png
# processing s40/8.png
# processing s40/9.png
# processing s40/10.png
